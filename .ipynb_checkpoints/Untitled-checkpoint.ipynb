# %%
import requests

# %%
requests.get('https://www.msn.cn')
# Out:
# <Response [200]>

# %%
import re
text = res.text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 import re
# ----> 2 text = res.text
#
# NameError: name 'res' is not defined

# %%
text = _.text
# Out:
#   Cell In[4], line 1
#     text = _.
#              ^
# SyntaxError: invalid syntax

# %%
re

# %%
text = _.text

# %%
text

# %%
print(text)
# Out:
# <?xml version="1.0" encoding="UTF-8" ?>
# <!DOCTYPE HTML PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.2//EN" "http://www.openmobilealliance.org/tech/DTD/xhtml-mobile12.dtd">
# <html xmlns="http://www.w3.org/1999/xhtml" xml:lang="zh-CN" dir="ltr">
#
# <head>
# ...

# %%
text = requests.get('https://msn.cn/weather/forecast')

# %%
text

# %%
text is None
# Out:
# False

# %%
text

# %%
print(text)
# Out:
# <Response [200]>

# %%
text = text.text

# %%
print()

# %%
print(text)
# Out:
# <!DOCTYPE html>
# <html lang="zh-cn" dir="ltr" >
# ...

# %%
re.search(r'\<script id="redux-data" type="application/json"\>([\s\S]+?)\</script\>')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 re.search(r'\<script id="redux-data" type="application/json"\>([\s\S]+?)\</script\>')
#
# TypeError: search() missing 1 required positional argument: 'string'
